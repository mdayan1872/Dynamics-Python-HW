# %%
           
from sympy import *    
from sympy.plotting import plot_parametric
from sympy.plotting import plot3d_parametric_line
import math

init_printing()

# %matplotlib inline  
t = symbols('t')

# Velocity B
x = -760*60 * sin(t)
y = 760*60 * cos(t)
plot_parametric(x, y, (t, -1*pi, 1*pi))

# Velocity C
a = -760*60*2 * sin(t)
b = 0
plot_parametric(a, b, (t, -1*pi, 1*pi))

# Position B
m = 760*60 * cos(t)
n = 760*60 * sin(t)
plot_parametric(m, n, (t, -1*pi, 1*pi))

# Position C
h = 760*60*2 * cos(t)
k = 0
plot_parametric(h, k, (t, -1*pi, 1*pi))
